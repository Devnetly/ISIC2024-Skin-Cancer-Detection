# %% [markdown]
# ### Import necessary libraries

# %%
import os
import sys
import torch
import optuna
import random
import numpy as np
import pandas as pd
import optuna
from tqdm.auto import tqdm
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import StratifiedGroupKFold, StratifiedKFold, GroupKFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl
import sys
import logging
sys.path.append('../..')
from definitions import ISIS_2024_DIR
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Device for inference

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Using {DEVICE} for inference')
# Out:
# Using cuda for inference

# %% [markdown]
# ### Reproducibility

# %%
def seed_everything(seed : int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# ### Global variables

# %%
DATA_DIR = "/kaggle/input/isic-2024-challenge"

# %%
N_SPLITS = 5
N_NEGATIVE = 91700
LGB_WEIGHTS = 0.4
CB_WEIGHTS = 0.6
EARLY_STOPPING_ROUNDS = 30

# %%
SEED = 42
seed_everything(SEED)

# %% [markdown]
# ### Data loading

# %%
train_meta_path = os.path.join(ISIS_2024_DIR, 'metadata.csv')
# test_meta_path = os.path.join(DATA_DIR, 'test-metadata.csv')

# %%
train_metadata = pd.read_csv(train_meta_path)
# test_metadata = pd.read_csv(test_meta_path)

# %%
train_metadata['age_approx'] = train_metadata['age_approx'].fillna(-1)
# test_metadata['age_approx'] = test_metadata['age_approx'].fillna(-1)

# %% [markdown]
# ### Columns

# %%
# Included only on train metadata
train_only_columns = ['lesion_id', 'iddx_full', 'iddx_1', 'iddx_2', 'iddx_3', 'iddx_4', 'iddx_5', 'mel_mitotic_index', 'mel_thick_mm', 'tbp_lv_dnn_lesion_confidence']

# Train and Test Features
general_features = ['age_approx', 'sex', 'tbp_tile_type']
color_features = ['tbp_lv_A', 'tbp_lv_Aext', 'tbp_lv_B', 'tbp_lv_Bext', 'tbp_lv_C', 'tbp_lv_Cext', 'tbp_lv_H', 'tbp_lv_Hext', 'tbp_lv_L', 'tbp_lv_Lext', 'tbp_lv_color_std_mean', 'tbp_lv_deltaA', 'tbp_lv_deltaB', 'tbp_lv_deltaL', 'tbp_lv_deltaLB', 'tbp_lv_deltaLBnorm', 'tbp_lv_norm_color', 'tbp_lv_radial_color_std_max', 'tbp_lv_stdL', 'tbp_lv_stdLExt']
shape_features = ['clin_size_long_diam_mm', 'tbp_lv_areaMM2', 'tbp_lv_perimeterMM', 'tbp_lv_area_perim_ratio', 'tbp_lv_eccentricity', 'tbp_lv_minorAxisMM']
location_features = ['anatom_site_general', 'tbp_lv_location', 'tbp_lv_x', 'tbp_lv_y', 'tbp_lv_z']
additional_features = ['tbp_lv_nevi_confidence', 'tbp_lv_norm_border', 'tbp_lv_symm_2axis', 'tbp_lv_symm_2axis_angle', 'attribution']
target = 'target'
group_col = 'patient_id'

# Drop features
drop_features = ['isic_id', 'image_type', 'copyright_license', 'tbp_lv_location_simple'] + train_only_columns

# %% [markdown]
# ### Downsampling

# %%
positive_samples = train_metadata[train_metadata['target'] == 1]
negative_samples = train_metadata[train_metadata['target'] == 0].sample(n=N_NEGATIVE, random_state=SEED)

#df = pd.concat([positive_samples, negative_samples], axis=0).reset_index(drop=True)

df = train_metadata.copy()

df.drop(drop_features, axis=1, inplace=True)

# %% [markdown]
# ### Feature engineering and aggregation

# %%
def aggregate_features(df):
    columns = []
    ### Ratio Aggregations ###

    df = pl.DataFrame(df)
        
    df = df.with_columns([
        
        # Ratio of A* to the product of A*ext and age minimum A*
        pl.col('tbp_lv_A').truediv(pl.col('tbp_lv_Aext').mul(pl.col('tbp_lv_A').min()))
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_ratio_A'),
        
        # Ratio of B* to the product of B*ext and age minimum B*
        pl.col('tbp_lv_B').truediv(pl.col('tbp_lv_Bext').mul(pl.col('tbp_lv_B').min()))
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_ratio_B'),
        
        # Ratio of C* to the product of C*ext and age minimum C*
        pl.col('tbp_lv_C').truediv(pl.col('tbp_lv_Cext').mul(pl.col('tbp_lv_C').min()))
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_ratio_C'),
        
        # Ratio of H* to the product of H*ext and age minimum H*
        pl.col('tbp_lv_H').truediv(pl.col('tbp_lv_Hext').mul(pl.col('tbp_lv_H').min()))
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_ratio_H'),
        
        # Ratio of L* to the product of L*ext and age minimum L*
        pl.col('tbp_lv_L').truediv(pl.col('tbp_lv_Lext').mul(pl.col('tbp_lv_L').min()))
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_ratio_L'),
        
    ])
    
    df = df.with_columns([
        
        # Contrast between A* and A*ext
        pl.col('tbp_lv_A').sub(pl.col('tbp_lv_Aext'))
        .cast(pl.Float32).alias('tbp_lv_contrast_A'),
        
        # Contrast between B* and B*ext
        pl.col('tbp_lv_B').sub(pl.col('tbp_lv_Bext'))
        .cast(pl.Float32).alias('tbp_lv_contrast_B'),
        
        # Contrast between C* and C*ext
        pl.col('tbp_lv_C').sub(pl.col('tbp_lv_Cext'))
        .cast(pl.Float32).alias('tbp_lv_contrast_C'),
        
        # Contrast between H* and H*ext
        pl.col('tbp_lv_H').sub(pl.col('tbp_lv_Hext'))
        .cast(pl.Float32).alias('tbp_lv_contrast_H'),
        
        # Contrast between L* and L*ext
        pl.col('tbp_lv_L').sub(pl.col('tbp_lv_Lext'))
        .cast(pl.Float32).alias('tbp_lv_contrast_L'), 
        
    ])
    
    df = df.with_columns([     
        
        # Ratio of tbp_lv_ratio_A to patient average
        pl.col('tbp_lv_ratio_A').truediv(pl.col('tbp_lv_ratio_A').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_ratio_A'),
        
        # Ratio of tbp_lv_ratio_B to patient average
        pl.col('tbp_lv_ratio_B').truediv(pl.col('tbp_lv_ratio_B').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_ratio_B'),
        
        # Ratio of tbp_lv_ratio_C to patient average
        pl.col('tbp_lv_ratio_C').truediv(pl.col('tbp_lv_ratio_C').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_ratio_C'),
        
        # Ratio of tbp_lv_ratio_H to patient average
        pl.col('tbp_lv_ratio_H').truediv(pl.col('tbp_lv_ratio_H').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_ratio_H'),
        
        # Ratio of tbp_lv_ratio_L to patient average
        pl.col('tbp_lv_ratio_L').truediv(pl.col('tbp_lv_ratio_L').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_ratio_L'),
        
    ])
    
    df = df.with_columns([     
        
        # Ratio of tbp_lv_contrast_A to patient average
        pl.col('tbp_lv_contrast_A').truediv(pl.col('tbp_lv_contrast_A').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_contrast_A'),
        
        # Ratio of tbp_lv_contrast_B to patient average
        pl.col('tbp_lv_contrast_B').truediv(pl.col('tbp_lv_contrast_B').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_contrast_B'),
        
        # Ratio of tbp_lv_contrast_C to patient average
        pl.col('tbp_lv_contrast_C').truediv(pl.col('tbp_lv_contrast_C').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_contrast_C'),
        
        # Ratio of tbp_lv_contrast_H to patient average
        pl.col('tbp_lv_contrast_H').truediv(pl.col('tbp_lv_contrast_H').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_contrast_H'),
        
        # Ratio of tbp_lv_contrast_L to patient average
        pl.col('tbp_lv_contrast_L').truediv(pl.col('tbp_lv_contrast_L').mean())
        .over('patient_id')
        .cast(pl.Float32).alias('tbp_lv_patient_contrast_L'),
        
    ])
    
    df = df.with_columns([     
        
        # Ratio of tbp_lv_ratio_A to age average
        pl.col('tbp_lv_ratio_A').truediv(pl.col('tbp_lv_ratio_A').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_ratio_A'),
        
        # Ratio of tbp_lv_ratio_B to age average
        pl.col('tbp_lv_ratio_B').truediv(pl.col('tbp_lv_ratio_B').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_ratio_B'),
        
        # Ratio of tbp_lv_ratio_C to age average
        pl.col('tbp_lv_ratio_C').truediv(pl.col('tbp_lv_ratio_C').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_ratio_C'),
        
        # Ratio of tbp_lv_ratio_H to age average
        pl.col('tbp_lv_ratio_H').truediv(pl.col('tbp_lv_ratio_H').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_ratio_H'),
        
        # Ratio of tbp_lv_ratio_L to age average
        pl.col('tbp_lv_ratio_L').truediv(pl.col('tbp_lv_ratio_L').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_ratio_L'),
        
    ])
    
    df = df.with_columns([     
        
        # Ratio of tbp_lv_contrast_A to age average
        pl.col('tbp_lv_contrast_A').truediv(pl.col('tbp_lv_contrast_A').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_contrast_A'),
        
        # Ratio of tbp_lv_contrast_B to age average
        pl.col('tbp_lv_contrast_B').truediv(pl.col('tbp_lv_contrast_B').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_contrast_B'),
        
        # Ratio of tbp_lv_contrast_C to age average
        pl.col('tbp_lv_contrast_C').truediv(pl.col('tbp_lv_contrast_C').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_contrast_C'),
        
        # Ratio of tbp_lv_contrast_H to age average
        pl.col('tbp_lv_contrast_H').truediv(pl.col('tbp_lv_contrast_H').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_contrast_H'),
        
        # Ratio of tbp_lv_contrast_L to age average
        pl.col('tbp_lv_contrast_L').truediv(pl.col('tbp_lv_contrast_L').mean())
        .over('age_approx')
        .cast(pl.Float32).alias('tbp_lv_age_contrast_L'),
        
    ]) 

    columns += ['tbp_lv_ratio_A', 'tbp_lv_ratio_B', 'tbp_lv_ratio_C', 'tbp_lv_ratio_H', 'tbp_lv_ratio_L']
    columns += ['tbp_lv_contrast_A', 'tbp_lv_contrast_B', 'tbp_lv_contrast_C', 'tbp_lv_contrast_H', 'tbp_lv_contrast_L']
    columns += ['tbp_lv_patient_ratio_A', 'tbp_lv_patient_ratio_B', 'tbp_lv_patient_ratio_C', 'tbp_lv_patient_ratio_H', 'tbp_lv_patient_ratio_L']
    columns += ['tbp_lv_patient_contrast_A', 'tbp_lv_patient_contrast_B', 'tbp_lv_patient_contrast_C', 'tbp_lv_patient_contrast_H', 'tbp_lv_patient_contrast_L']
    columns += ['tbp_lv_age_ratio_A', 'tbp_lv_age_ratio_B', 'tbp_lv_age_ratio_C', 'tbp_lv_age_ratio_H', 'tbp_lv_age_ratio_L']
    columns += ['tbp_lv_age_contrast_A', 'tbp_lv_age_contrast_B', 'tbp_lv_age_contrast_C', 'tbp_lv_age_contrast_H', 'tbp_lv_age_contrast_L']

    return df, columns

# %%
df, new_cols = aggregate_features(df)
df = df.to_pandas()

"""test_df = test_metadata.copy()

test_df, _ = aggregate_features(test_df)
test_df = test_df.to_pandas()
test_df.drop(columns=['isic_id', 'image_type', 'copyright_license', 'tbp_lv_location_simple', 'patient_id'], inplace=True)"""
# Out:
# "test_df = test_metadata.copy()\n\ntest_df, _ = aggregate_features(test_df)\ntest_df = test_df.to_pandas()\ntest_df.drop(columns=['isic_id', 'image_type', 'copyright_license', 'tbp_lv_location_simple', 'patient_id'], inplace=True)"

# %% [markdown]
# ### Encoding

# %%
train_cols = general_features + color_features + shape_features + location_features + additional_features + new_cols
categorical_cols = df[train_cols].select_dtypes(include=['object']).columns
num_features = df[train_cols].select_dtypes(include=[np.number]).columns

# cast numerical columns to float32
df[num_features] = df[num_features].astype('float32')
# test_df[num_features] = test_df[num_features].astype('float32')

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# sex                    11517
# anatom_site_general     5756
# dtype: int64

# %%
df[categorical_cols] = df[categorical_cols].fillna('missing')
# test_df[categorical_cols] = test_df[categorical_cols].fillna('missing')

# %% [markdown]
# ### Partial AUC

# %%
import pandas.api.types
from sklearn.metrics import roc_curve, auc, roc_auc_score

def pauc_score(solution: pd.DataFrame, submission: pd.DataFrame, min_tpr: float=0.80) -> float:
    '''
    2024 ISIC Challenge metric: pAUC
    
    Given a solution file and submission file, this function returns the
    the partial area under the receiver operating characteristic (pAUC) 
    above a given true positive rate (TPR) = 0.80.
    https://en.wikipedia.org/wiki/Partial_Area_Under_the_ROC_Curve.
    
    (c) 2024 Nicholas R Kurtansky, MSKCC

    Args:
        solution: ground truth pd.DataFrame of 1s and 0s
        submission: solution dataframe of predictions of scores ranging [0, 1]

    Returns:
        Float value range [0, max_fpr]
    '''



    # check submission is numeric
    if not pandas.api.types.is_numeric_dtype(submission.values):
        raise ValueError("Expected numeric values in submission, got: %r" % submission.values)
    
    # rescale the target. set 0s to 1s and 1s to 0s (since sklearn only has max_fpr)
    v_gt = abs(np.asarray(solution.values)-1)
    
    # flip the submissions to their compliments
    v_pred = -1.0*np.asarray(submission.values)

    max_fpr = abs(1-min_tpr)

    # using sklearn.metric functions: (1) roc_curve and (2) auc
    fpr, tpr, _ = roc_curve(v_gt, v_pred, sample_weight=None)
    if max_fpr is None or max_fpr == 1:
        return auc(fpr, tpr)
    if max_fpr <= 0 or max_fpr > 1:
        raise ValueError("Expected min_tpr in range [0, 1), got: %r" % min_tpr)
        
    # Add a single point at max_fpr by linear interpolation
    stop = np.searchsorted(fpr, max_fpr, "right")
    x_interp = [fpr[stop - 1], fpr[stop]]
    y_interp = [tpr[stop - 1], tpr[stop]]
    tpr = np.append(tpr[:stop], np.interp(max_fpr, x_interp, y_interp))
    fpr = np.append(fpr[:stop], max_fpr)
    partial_auc = auc(fpr, tpr)

#     # Equivalent code that uses sklearn's roc_auc_score
#     v_gt = abs(np.asarray(solution.values)-1)
#     v_pred = np.array([1.0 - x for x in submission.values])
#     max_fpr = abs(1-min_tpr)
#     partial_auc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
#     # change scale from [0.5, 1.0] to [0.5 * max_fpr**2, max_fpr]
#     # https://math.stackexchange.com/questions/914823/shift-numbers-into-a-different-range
#     partial_auc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (partial_auc_scaled - 0.5)
    
    return(partial_auc)

# %% [markdown]
# ### Cross Validation Setup

# %%
sgkf = StratifiedGroupKFold(n_splits=N_SPLITS)
"""
df['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(sgkf.split(df, df[target], df[group_col])):
    df.loc[val_idx, 'fold'] = fold
"""
# Out:
# "\ndf['fold'] = -1\nfor fold, (train_idx, val_idx) in enumerate(sgkf.split(df, df[target], df[group_col])):\n    df.loc[val_idx, 'fold'] = fold\n"

# %% [markdown]
# ### LightGBM Training

# %%
def train_lgb(data, cat_cols, train_cols, params, early_stoping_rounds,pos_weight=1.0):

    # Convert categorical columns to category type
    for col in cat_cols:
        data[col] = data[col].astype('category')

    # Split features and label
    X = data[train_cols]
    y = data[target]
    groups = data[group_col]

    cat_features = [X.columns.get_loc(col) for col in cat_cols]

    # Initialize variables
    models = []
    scores = []

    # Perform cross-validation
    for fold, (train_idx, val_idx) in enumerate(sgkf.split(X, y, groups)):

        # Split data
        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
        
        weights = np.array([(1.0 if label == 0 else pos_weight) for label in y_train])

        # Creat LightGBM datasets
        train_data = lgb.Dataset(X_train, label=y_train,weight=weights,categorical_feature=cat_features)
        val_data = lgb.Dataset(X_val, label=y_val, categorical_feature=cat_features)

        # Train model
        model = lgb.train(params, train_data, valid_sets=[val_data], callbacks=[lgb.early_stopping(early_stoping_rounds, verbose=0), lgb.log_evaluation(0)])

        # Predict validation data
        y_pred = model.predict(X_val)

        # Calculate PAUC
        score = pauc_score(pd.DataFrame(y_val, columns=['target']), pd.DataFrame(y_pred, columns=['prediction']))
        print(f'Fold {fold+1} - PAUC: {score}')

        
        # Append model and score
        models.append(model)
        scores.append(score)
    
    return models, scores

# %% [markdown]
# - Baseline model

# %%
### LightGBM parameters
lgb_params = {
    'seed': SEED,
    'objective': 'binary',
    'boosting_type': 'gbdt',
    'min_child_samples': 48,
    'num_iterations': 3000,
    'learning_rate': 0.03,
    'extra_trees': True,
    'metric': 'binary_logloss',
    'reg_alpha': 0.1,
    'reg_lambda': 0.8,
    'num_leaves': 64,
    'device': 'gpu',
    'max_bin': 128,
    'max_depth': 4,
    'verbose': -1
}

### CatBoost parameters
cb_params = {
    'random_seed': SEED,
    'grow_policy': 'Depthwise',
    'loss_function': 'Logloss',
    'min_child_samples': 48,
    'learning_rate': 0.03,
    'task_type': 'GPU',
    'reg_lambda': 0.8,
    'num_leaves': 3000,
    'depth': 4
}

# %%
models, scores = train_lgb(df, categorical_cols, train_cols, lgb_params, EARLY_STOPPING_ROUNDS)
# Out:
# Fold 1 - PAUC: 0.17517988538029966
# Fold 2 - PAUC: 0.16151157736407795
# Fold 3 - PAUC: 0.16284337545241287
# Fold 4 - PAUC: 0.15494436012948978
# Fold 5 - PAUC: 0.16490062543748288

# %%
print(f'Average PAUC: {np.mean(scores)}')
print(f'STD PAUC: {np.std(scores)}')
# Out:
# Average PAUC: 0.16387596475275262
# STD PAUC: 0.006561382180697987

# %% [markdown]
# ### Hyper-parameter tuning

# %%
top_k_models = {}
k = 5

# %%
def objective(trial: optuna.Trial) -> float:
    
    lgb_params = {
        'seed': SEED,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'min_child_samples': trial.suggest_int("min_child_samples", 5, 500),
        'num_iterations': trial.suggest_int("n_estimators", 100, 10000, step=100),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 0.3),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "max_depth": trial.suggest_int("max_depth", 2, 128),
        'device': 'gpu',
        'verbose': -1,
        "subsample": trial.suggest_float("subsample", 0.4, 1),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1),
    }
    
    pos_class_weight = trial.suggest_float("pos_class_weight", 1, 1200)
    models, scores = train_lgb(df, categorical_cols, train_cols, lgb_params, EARLY_STOPPING_ROUNDS, pos_class_weight)

    mean = np.mean(scores)

    return mean

# %%
def load_or_create_study(study_name: str) -> optuna.study.Study:

    sampler = optuna.samplers.TPESampler(seed=SEED)

    if not os.path.exists('./sampler.pkl'):
        with open('./sampler.pkl', 'wb') as f:
            pickle.dump(sampler, f)
    else:
        with open('./sampler.pkl', 'rb') as f:
            sampler = pickle.load(f)

    study = optuna.create_study(
        direction="maximize", 
        study_name=study_name, 
        storage=f"sqlite:///{study_name}.db",
        load_if_exists=True,
        sampler=sampler
    )

    return study

# %%
study = load_or_create_study('lgbm_optuna')
# Out:
# Using an existing study with name 'lgbm_optuna' instead of creating a new one.
# [I 2024-08-01 17:39:21,043] Using an existing study with name 'lgbm_optuna' instead of creating a new one.

# %%
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 - PAUC: 0.15875363311907095
# Fold 2 - PAUC: 0.14701910483459799
# Fold 3 - PAUC: 0.14391068438464638
# Fold 4 - PAUC: 0.15342230720913655
# Fold 5 - PAUC: 0.1496480283347117
# Trial 1 finished with value: 0.15055075157643272 and parameters: {'min_child_samples': 190, 'n_estimators': 9600, 'learning_rate': 0.035093904781414616, 'reg_alpha': 0.24810409748678125, 'reg_lambda': 0.004207988669606638, 'num_leaves': 41, 'max_depth': 9, 'subsample': 0.9197056874649611, 'colsample_bytree': 0.7606690070459252, 'pos_class_weight': 849.9790207774586}. Best is trial 1 with value: 0.15055075157643272.
# [I 2024-08-01 17:40:21,085] Trial 1 finished with value: 0.15055075157643272 and parameters: {'min_child_samples': 190, 'n_estimators': 9600, 'learning_rate': 0.035093904781414616, 'reg_alpha': 0.24810409748678125, 'reg_lambda': 0.004207988669606638, 'num_leaves': 41, 'max_depth': 9, 'subsample': 0.9197056874649611, 'colsample_bytree': 0.7606690070459252, 'pos_class_weight': 849.9790207774586}. Best is trial 1 with value: 0.15055075157643272.
# Fold 1 - PAUC: 0.1626662677677228
# Fold 2 - PAUC: 0.146048609848777
# Fold 3 - PAUC: 0.15517653823595193
# Fold 4 - PAUC: 0.15640244887745913
# Fold 5 - PAUC: 0.15100729452869016
# Trial 2 finished with value: 0.1542602318517202 and parameters: {'min_child_samples': 15, 'n_estimators': 9700, 'learning_rate': 0.07843393422707806, 'reg_alpha': 0.0070689749506246055, 'reg_lambda': 0.005337032762603957, 'num_leaves': 48, 'max_depth': 40, 'subsample': 0.7148538589793427, 'colsample_bytree': 0.6591670111852694, 'pos_class_weight': 350.18373909745225}. Best is trial 2 with value: 0.1542602318517202.
# [I 2024-08-01 17:40:46,309] Trial 2 finished with value: 0.1542602318517202 and parameters: {'min_child_samples': 15, 'n_estimators': 9700, 'learning_rate': 0.07843393422707806, 'reg_alpha': 0.0070689749506246055, 'reg_lambda': 0.005337032762603957, 'num_leaves': 48, 'max_depth': 40, 'subsample': 0.7148538589793427, 'colsample_bytree': 0.6591670111852694, 'pos_class_weight': 350.18373909745225}. Best is trial 2 with value: 0.1542602318517202.
# Fold 1 - PAUC: 0.1605876066679221
# Fold 2 - PAUC: 0.1440296771677327
# Fold 3 - PAUC: 0.17268237068693806
# Fold 4 - PAUC: 0.1551017587107587
# Fold 5 - PAUC: 0.15031237839818573
# Trial 3 finished with value: 0.15654275832630743 and parameters: {'min_child_samples': 308, 'n_estimators': 1400, 'learning_rate': 0.0010371041375055886, 'reg_alpha': 0.029204338471814112, 'reg_lambda': 0.06672367170464207, 'num_leaves': 202, 'max_depth': 27, 'subsample': 0.708540663048167, 'colsample_bytree': 0.7554487413172255, 'pos_class_weight': 56.69404485127727}. Best is trial 3 with value: 0.15654275832630743.
# [I 2024-08-01 17:43:41,967] Trial 3 finished with value: 0.15654275832630743 and parameters: {'min_child_samples': 308, 'n_estimators': 1400, 'learning_rate': 0.0010371041375055886, 'reg_alpha': 0.029204338471814112, 'reg_lambda': 0.06672367170464207, 'num_leaves': 202, 'max_depth': 27, 'subsample': 0.708540663048167, 'colsample_bytree': 0.7554487413172255, 'pos_class_weight': 56.69404485127727}. Best is trial 3 with value: 0.15654275832630743.
# Fold 1 - PAUC: 0.15239791531003746
# Fold 2 - PAUC: 0.1341193759350982
# Fold 3 - PAUC: 0.1661983426911733
# Fold 4 - PAUC: 0.1440077825742907
# Fold 5 - PAUC: 0.15118543992041797
# Trial 4 finished with value: 0.14958177128620354 and parameters: {'min_child_samples': 306, 'n_estimators': 1800, 'learning_rate': 0.0001683419201821694, 'reg_alpha': 6.245139574743075, 'reg_lambda': 7.2866537374910445, 'num_leaves': 208, 'max_depth': 40, 'subsample': 0.45860326840383037, 'colsample_bytree': 0.8105398159072941, 'pos_class_weight': 528.742839993782}. Best is trial 3 with value: 0.15654275832630743.
# [I 2024-08-01 17:47:15,675] Trial 4 finished with value: 0.14958177128620354 and parameters: {'min_child_samples': 306, 'n_estimators': 1800, 'learning_rate': 0.0001683419201821694, 'reg_alpha': 6.245139574743075, 'reg_lambda': 7.2866537374910445, 'num_leaves': 208, 'max_depth': 40, 'subsample': 0.45860326840383037, 'colsample_bytree': 0.8105398159072941, 'pos_class_weight': 528.742839993782}. Best is trial 3 with value: 0.15654275832630743.
# Fold 1 - PAUC: 0.15669007658924544
# Fold 2 - PAUC: 0.13809240932131053
# Fold 3 - PAUC: 0.16914200654232847
# Fold 4 - PAUC: 0.15375851109069627
# Fold 5 - PAUC: 0.15832947205789852
# Trial 5 finished with value: 0.15520249512029585 and parameters: {'min_child_samples': 65, 'n_estimators': 5000, 'learning_rate': 0.00013169614353741142, 'reg_alpha': 4.337920697490942, 'reg_lambda': 0.010842262717330166, 'num_leaves': 170, 'max_depth': 41, 'subsample': 0.7120408127066865, 'colsample_bytree': 0.7280261676059678, 'pos_class_weight': 222.6404921751069}. Best is trial 3 with value: 0.15654275832630743.
# [I 2024-08-01 18:02:41,372] Trial 5 finished with value: 0.15520249512029585 and parameters: {'min_child_samples': 65, 'n_estimators': 5000, 'learning_rate': 0.00013169614353741142, 'reg_alpha': 4.337920697490942, 'reg_lambda': 0.010842262717330166, 'num_leaves': 170, 'max_depth': 41, 'subsample': 0.7120408127066865, 'colsample_bytree': 0.7280261676059678, 'pos_class_weight': 222.6404921751069}. Best is trial 3 with value: 0.15654275832630743.
# Fold 1 - PAUC: 0.16463501556969992
# Fold 2 - PAUC: 0.15239390417046117
# Fold 3 - PAUC: 0.165614889605006
# Fold 4 - PAUC: 0.14561253454593276
# Fold 5 - PAUC: 0.12678642536004667
# Trial 6 finished with value: 0.15100855385022932 and parameters: {'min_child_samples': 485, 'n_estimators': 7800, 'learning_rate': 0.18482117991817734, 'reg_alpha': 3.7958531426706403, 'reg_lambda': 0.24637685958997463, 'num_leaves': 237, 'max_depth': 13, 'subsample': 0.5175897174514872, 'colsample_bytree': 0.4271363733463229, 'pos_class_weight': 391.07106658515397}. Best is trial 3 with value: 0.15654275832630743.
# [I 2024-08-01 18:02:57,927] Trial 6 finished with value: 0.15100855385022932 and parameters: {'min_child_samples': 485, 'n_estimators': 7800, 'learning_rate': 0.18482117991817734, 'reg_alpha': 3.7958531426706403, 'reg_lambda': 0.24637685958997463, 'num_leaves': 237, 'max_depth': 13, 'subsample': 0.5175897174514872, 'colsample_bytree': 0.4271363733463229, 'pos_class_weight': 391.07106658515397}. Best is trial 3 with value: 0.15654275832630743.
# Fold 1 - PAUC: 0.1584692069355258
# Fold 2 - PAUC: 0.15812861719800467
# Fold 3 - PAUC: 0.1700906217771928
# Fold 4 - PAUC: 0.1512543409402381
# Fold 5 - PAUC: 0.16258175328970126
# Trial 7 finished with value: 0.16010490802813251 and parameters: {'min_child_samples': 197, 'n_estimators': 2800, 'learning_rate': 0.07614139119869383, 'reg_alpha': 0.026730883107816707, 'reg_lambda': 0.013296521457299506, 'num_leaves': 140, 'max_depth': 19, 'subsample': 0.8813181884524238, 'colsample_bytree': 0.44473038620786254, 'pos_class_weight': 1184.2774369840201}. Best is trial 7 with value: 0.16010490802813251.
# [I 2024-08-01 18:03:25,329] Trial 7 finished with value: 0.16010490802813251 and parameters: {'min_child_samples': 197, 'n_estimators': 2800, 'learning_rate': 0.07614139119869383, 'reg_alpha': 0.026730883107816707, 'reg_lambda': 0.013296521457299506, 'num_leaves': 140, 'max_depth': 19, 'subsample': 0.8813181884524238, 'colsample_bytree': 0.44473038620786254, 'pos_class_weight': 1184.2774369840201}. Best is trial 7 with value: 0.16010490802813251.
# Fold 1 - PAUC: 0.15954221484208753
# Fold 2 - PAUC: 0.14350497719228528
# Fold 3 - PAUC: 0.17325392048539814
# Fold 4 - PAUC: 0.1547807539196854
# Fold 5 - PAUC: 0.15397252716709117
# Trial 8 finished with value: 0.1570108787213095 and parameters: {'min_child_samples': 388, 'n_estimators': 2000, 'learning_rate': 0.00010452040185705873, 'reg_alpha': 1.8274508859816028, 'reg_lambda': 0.6720930050156113, 'num_leaves': 187, 'max_depth': 99, 'subsample': 0.44442679104045424, 'colsample_bytree': 0.6150794371265635, 'pos_class_weight': 139.92700237063053}. Best is trial 7 with value: 0.16010490802813251.
# [I 2024-08-01 18:07:16,686] Trial 8 finished with value: 0.1570108787213095 and parameters: {'min_child_samples': 388, 'n_estimators': 2000, 'learning_rate': 0.00010452040185705873, 'reg_alpha': 1.8274508859816028, 'reg_lambda': 0.6720930050156113, 'num_leaves': 187, 'max_depth': 99, 'subsample': 0.44442679104045424, 'colsample_bytree': 0.6150794371265635, 'pos_class_weight': 139.92700237063053}. Best is trial 7 with value: 0.16010490802813251.
# Fold 1 - PAUC: 0.1629516015219961
# Fold 2 - PAUC: 0.15180307918807867
# Fold 3 - PAUC: 0.15267204810464138
# Fold 4 - PAUC: 0.15222426689986865
# Fold 5 - PAUC: 0.15336736441899101
# Trial 9 finished with value: 0.15460367202671516 and parameters: {'min_child_samples': 433, 'n_estimators': 6300, 'learning_rate': 0.0014144010020808167, 'reg_alpha': 0.0017956984225677636, 'reg_lambda': 0.017535949529764425, 'num_leaves': 84, 'max_depth': 94, 'subsample': 0.7825344828131279, 'colsample_bytree': 0.932327645545796, 'pos_class_weight': 567.1856952691772}. Best is trial 7 with value: 0.16010490802813251.
# [I 2024-08-01 18:21:42,133] Trial 9 finished with value: 0.15460367202671516 and parameters: {'min_child_samples': 433, 'n_estimators': 6300, 'learning_rate': 0.0014144010020808167, 'reg_alpha': 0.0017956984225677636, 'reg_lambda': 0.017535949529764425, 'num_leaves': 84, 'max_depth': 94, 'subsample': 0.7825344828131279, 'colsample_bytree': 0.932327645545796, 'pos_class_weight': 567.1856952691772}. Best is trial 7 with value: 0.16010490802813251.
# Fold 1 - PAUC: 0.16912972718748043
# Fold 2 - PAUC: 0.15875245957812004
# Fold 3 - PAUC: 0.17584563739705814
# Fold 4 - PAUC: 0.1535239651259268
# Fold 5 - PAUC: 0.1629806356024019
# Trial 10 finished with value: 0.16404648497819746 and parameters: {'min_child_samples': 64, 'n_estimators': 7200, 'learning_rate': 0.0441918174422801, 'reg_alpha': 0.17583640270008521, 'reg_lambda': 1.2130221181165162, 'num_leaves': 127, 'max_depth': 68, 'subsample': 0.6565246110151297, 'colsample_bytree': 0.4152514760464571, 'pos_class_weight': 130.36182096497203}. Best is trial 10 with value: 0.16404648497819746.
# [I 2024-08-01 18:22:13,200] Trial 10 finished with value: 0.16404648497819746 and parameters: {'min_child_samples': 64, 'n_estimators': 7200, 'learning_rate': 0.0441918174422801, 'reg_alpha': 0.17583640270008521, 'reg_lambda': 1.2130221181165162, 'num_leaves': 127, 'max_depth': 68, 'subsample': 0.6565246110151297, 'colsample_bytree': 0.4152514760464571, 'pos_class_weight': 130.36182096497203}. Best is trial 10 with value: 0.16404648497819746.
# Fold 1 - PAUC: 0.16976291983654648
# Fold 2 - PAUC: 0.16260361726942205
# Fold 3 - PAUC: 0.16932490759752933
# Fold 4 - PAUC: 0.1538790798758602
# Fold 5 - PAUC: 0.1561676764327357
# Trial 11 finished with value: 0.1623476402024188 and parameters: {'min_child_samples': 107, 'n_estimators': 4800, 'learning_rate': 0.013188520890798841, 'reg_alpha': 0.3624038247549039, 'reg_lambda': 3.702357557972249, 'num_leaves': 101, 'max_depth': 72, 'subsample': 0.5734355557502415, 'colsample_bytree': 0.5284950174483743, 'pos_class_weight': 802.4226589562269}. Best is trial 10 with value: 0.16404648497819746.
# [I 2024-08-01 18:24:10,403] Trial 11 finished with value: 0.1623476402024188 and parameters: {'min_child_samples': 107, 'n_estimators': 4800, 'learning_rate': 0.013188520890798841, 'reg_alpha': 0.3624038247549039, 'reg_lambda': 3.702357557972249, 'num_leaves': 101, 'max_depth': 72, 'subsample': 0.5734355557502415, 'colsample_bytree': 0.5284950174483743, 'pos_class_weight': 802.4226589562269}. Best is trial 10 with value: 0.16404648497819746.
# Fold 1 - PAUC: 0.17036512542789525
# Fold 2 - PAUC: 0.15711488084793968
# Fold 3 - PAUC: 0.1719310236475449
# Fold 4 - PAUC: 0.15650877851469364
# Fold 5 - PAUC: 0.1525610425913671
# Trial 12 finished with value: 0.1616961702058881 and parameters: {'min_child_samples': 96, 'n_estimators': 4400, 'learning_rate': 0.011764504617720207, 'reg_alpha': 0.3655531407273296, 'reg_lambda': 3.8568176786757036, 'num_leaves': 101, 'max_depth': 72, 'subsample': 0.5768233081877587, 'colsample_bytree': 0.5295016244277313, 'pos_class_weight': 851.4561272827108}. Best is trial 10 with value: 0.16404648497819746.
# [I 2024-08-01 18:26:24,166] Trial 12 finished with value: 0.1616961702058881 and parameters: {'min_child_samples': 96, 'n_estimators': 4400, 'learning_rate': 0.011764504617720207, 'reg_alpha': 0.3655531407273296, 'reg_lambda': 3.8568176786757036, 'num_leaves': 101, 'max_depth': 72, 'subsample': 0.5768233081877587, 'colsample_bytree': 0.5295016244277313, 'pos_class_weight': 851.4561272827108}. Best is trial 10 with value: 0.16404648497819746.
# Fold 1 - PAUC: 0.17188789945672164
# Fold 2 - PAUC: 0.15867355461304614
# Fold 3 - PAUC: 0.16972414770700117
# Fold 4 - PAUC: 0.15669452739948037
# Fold 5 - PAUC: 0.15571038473213603
# Trial 13 finished with value: 0.16253810278167707 and parameters: {'min_child_samples': 132, 'n_estimators': 7000, 'learning_rate': 0.007824989029204164, 'reg_alpha': 0.5293304975639905, 'reg_lambda': 1.2237594247191281, 'num_leaves': 129, 'max_depth': 123, 'subsample': 0.6056795729597898, 'colsample_bytree': 0.5405653765683788, 'pos_class_weight': 801.0274869638835}. Best is trial 10 with value: 0.16404648497819746.
# [I 2024-08-01 18:29:32,290] Trial 13 finished with value: 0.16253810278167707 and parameters: {'min_child_samples': 132, 'n_estimators': 7000, 'learning_rate': 0.007824989029204164, 'reg_alpha': 0.5293304975639905, 'reg_lambda': 1.2237594247191281, 'num_leaves': 129, 'max_depth': 123, 'subsample': 0.6056795729597898, 'colsample_bytree': 0.5405653765683788, 'pos_class_weight': 801.0274869638835}. Best is trial 10 with value: 0.16404648497819746.
# Fold 1 - PAUC: 0.17013071287411766
# Fold 2 - PAUC: 0.15891032964924726
# Fold 3 - PAUC: 0.17331929257353237
# Fold 4 - PAUC: 0.1592265678821779
# Fold 5 - PAUC: 0.1549339806986469
# Trial 14 finished with value: 0.1633041767355444 and parameters: {'min_child_samples': 193, 'n_estimators': 7300, 'learning_rate': 0.002669199316500576, 'reg_alpha': 0.8745680847717868, 'reg_lambda': 0.9385195281013483, 'num_leaves': 146, 'max_depth': 126, 'subsample': 0.6097442162986932, 'colsample_bytree': 0.5183515057905005, 'pos_class_weight': 1055.6570981450882}. Best is trial 10 with value: 0.16404648497819746.
# [I 2024-08-01 18:39:29,941] Trial 14 finished with value: 0.1633041767355444 and parameters: {'min_child_samples': 193, 'n_estimators': 7300, 'learning_rate': 0.002669199316500576, 'reg_alpha': 0.8745680847717868, 'reg_lambda': 0.9385195281013483, 'num_leaves': 146, 'max_depth': 126, 'subsample': 0.6097442162986932, 'colsample_bytree': 0.5183515057905005, 'pos_class_weight': 1055.6570981450882}. Best is trial 10 with value: 0.16404648497819746.
# Fold 1 - PAUC: 0.17146195706607015
# Fold 2 - PAUC: 0.1547557607164835
# Fold 3 - PAUC: 0.1745378116573504
# Fold 4 - PAUC: 0.16097939099324293
# Fold 5 - PAUC: 0.16160940877349844
# Trial 15 finished with value: 0.16466886584132912 and parameters: {'min_child_samples': 210, 'n_estimators': 8200, 'learning_rate': 0.001986655664011542, 'reg_alpha': 0.057121139494386, 'reg_lambda': 0.17114390413349748, 'num_leaves': 137, 'max_depth': 128, 'subsample': 0.6298599862965508, 'colsample_bytree': 0.4065935135462628, 'pos_class_weight': 1139.6758456926877}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 18:51:33,419] Trial 15 finished with value: 0.16466886584132912 and parameters: {'min_child_samples': 210, 'n_estimators': 8200, 'learning_rate': 0.001986655664011542, 'reg_alpha': 0.057121139494386, 'reg_lambda': 0.17114390413349748, 'num_leaves': 137, 'max_depth': 128, 'subsample': 0.6298599862965508, 'colsample_bytree': 0.4065935135462628, 'pos_class_weight': 1139.6758456926877}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1670429627776072
# Fold 2 - PAUC: 0.15579674093025164
# Fold 3 - PAUC: 0.1664696224577921
# Fold 4 - PAUC: 0.15752337380131168
# Fold 5 - PAUC: 0.16340674537672026
# Trial 16 finished with value: 0.16204788906873657 and parameters: {'min_child_samples': 283, 'n_estimators': 8500, 'learning_rate': 0.0005577716339164532, 'reg_alpha': 0.07312301821212806, 'reg_lambda': 0.0010446251525877384, 'num_leaves': 7, 'max_depth': 100, 'subsample': 0.803963074458796, 'colsample_bytree': 0.4017599390935732, 'pos_class_weight': 1031.7202003594662}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 18:56:38,034] Trial 16 finished with value: 0.16204788906873657 and parameters: {'min_child_samples': 283, 'n_estimators': 8500, 'learning_rate': 0.0005577716339164532, 'reg_alpha': 0.07312301821212806, 'reg_lambda': 0.0010446251525877384, 'num_leaves': 7, 'max_depth': 100, 'subsample': 0.803963074458796, 'colsample_bytree': 0.4017599390935732, 'pos_class_weight': 1031.7202003594662}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1565201987968853
# Fold 2 - PAUC: 0.1497360337234528
# Fold 3 - PAUC: 0.17200561118422666
# Fold 4 - PAUC: 0.15178038946149458
# Fold 5 - PAUC: 0.15281043317432816
# Trial 17 finished with value: 0.15657053326807752 and parameters: {'min_child_samples': 6, 'n_estimators': 8500, 'learning_rate': 0.003252049234507857, 'reg_alpha': 0.09204267087050635, 'reg_lambda': 0.17365086451445597, 'num_leaves': 162, 'max_depth': 55, 'subsample': 0.6626955779129008, 'colsample_bytree': 0.5964943525856926, 'pos_class_weight': 334.7264721961983}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:03:17,453] Trial 17 finished with value: 0.15657053326807752 and parameters: {'min_child_samples': 6, 'n_estimators': 8500, 'learning_rate': 0.003252049234507857, 'reg_alpha': 0.09204267087050635, 'reg_lambda': 0.17365086451445597, 'num_leaves': 162, 'max_depth': 55, 'subsample': 0.6626955779129008, 'colsample_bytree': 0.5964943525856926, 'pos_class_weight': 334.7264721961983}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.16034421564658416
# Fold 2 - PAUC: 0.15089916026653877
# Fold 3 - PAUC: 0.17012610765371797
# Fold 4 - PAUC: 0.1569192499520828
# Fold 5 - PAUC: 0.1533858077828726
# Trial 18 finished with value: 0.15833490826035926 and parameters: {'min_child_samples': 238, 'n_estimators': 6200, 'learning_rate': 0.03353590548501958, 'reg_alpha': 0.01297707724384525, 'reg_lambda': 0.39167975807109956, 'num_leaves': 119, 'max_depth': 112, 'subsample': 0.793626300652922, 'colsample_bytree': 0.468653371485457, 'pos_class_weight': 667.0548066388467}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:04:05,860] Trial 18 finished with value: 0.15833490826035926 and parameters: {'min_child_samples': 238, 'n_estimators': 6200, 'learning_rate': 0.03353590548501958, 'reg_alpha': 0.01297707724384525, 'reg_lambda': 0.39167975807109956, 'num_leaves': 119, 'max_depth': 112, 'subsample': 0.793626300652922, 'colsample_bytree': 0.468653371485457, 'pos_class_weight': 667.0548066388467}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.15876786253155828
# Fold 2 - PAUC: 0.12528995845611485
# Fold 3 - PAUC: 0.14664645667603246
# Fold 4 - PAUC: 0.13852540663966664
# Fold 5 - PAUC: 0.14249978242340935
# Trial 19 finished with value: 0.1423458933453563 and parameters: {'min_child_samples': 167, 'n_estimators': 6000, 'learning_rate': 0.03434731621810434, 'reg_alpha': 0.0035672925079159373, 'reg_lambda': 0.05338646243349568, 'num_leaves': 64, 'max_depth': 89, 'subsample': 0.5087723746089318, 'colsample_bytree': 0.9801412264613572, 'pos_class_weight': 1179.2044363281375}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:04:57,552] Trial 19 finished with value: 0.1423458933453563 and parameters: {'min_child_samples': 167, 'n_estimators': 6000, 'learning_rate': 0.03434731621810434, 'reg_alpha': 0.0035672925079159373, 'reg_lambda': 0.05338646243349568, 'num_leaves': 64, 'max_depth': 89, 'subsample': 0.5087723746089318, 'colsample_bytree': 0.9801412264613572, 'pos_class_weight': 1179.2044363281375}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.0004839199535583091
# Fold 2 - PAUC: 0.05926098163008814
# Fold 3 - PAUC: 0.10128616303600389
# Fold 4 - PAUC: 0.07869113112271357
# Fold 5 - PAUC: 0.03163484213987748
# Trial 20 finished with value: 0.054271407576448286 and parameters: {'min_child_samples': 51, 'n_estimators': 3900, 'learning_rate': 0.2910693383130123, 'reg_alpha': 0.15233952057715977, 'reg_lambda': 1.6904150397119075, 'num_leaves': 232, 'max_depth': 84, 'subsample': 0.9887878520549762, 'colsample_bytree': 0.830031445840551, 'pos_class_weight': 1.7796429405210574}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:05:10,148] Trial 20 finished with value: 0.054271407576448286 and parameters: {'min_child_samples': 51, 'n_estimators': 3900, 'learning_rate': 0.2910693383130123, 'reg_alpha': 0.15233952057715977, 'reg_lambda': 1.6904150397119075, 'num_leaves': 232, 'max_depth': 84, 'subsample': 0.9887878520549762, 'colsample_bytree': 0.830031445840551, 'pos_class_weight': 1.7796429405210574}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.174171477061636
# Fold 2 - PAUC: 0.15412286711895684
# Fold 3 - PAUC: 0.16428463320754882
# Fold 4 - PAUC: 0.15666572912276924
# Fold 5 - PAUC: 0.15545431693834968
# Trial 21 finished with value: 0.1609398046898521 and parameters: {'min_child_samples': 368, 'n_estimators': 8700, 'learning_rate': 0.005035108245599503, 'reg_alpha': 0.05246845012264979, 'reg_lambda': 0.09793754393746598, 'num_leaves': 84, 'max_depth': 60, 'subsample': 0.6433805151389402, 'colsample_bytree': 0.48232902201374495, 'pos_class_weight': 682.3979487952859}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:09:29,675] Trial 21 finished with value: 0.1609398046898521 and parameters: {'min_child_samples': 368, 'n_estimators': 8700, 'learning_rate': 0.005035108245599503, 'reg_alpha': 0.05246845012264979, 'reg_lambda': 0.09793754393746598, 'num_leaves': 84, 'max_depth': 60, 'subsample': 0.6433805151389402, 'colsample_bytree': 0.48232902201374495, 'pos_class_weight': 682.3979487952859}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1690180635746812
# Fold 2 - PAUC: 0.15743672529961106
# Fold 3 - PAUC: 0.17424234133829425
# Fold 4 - PAUC: 0.15924743063375085
# Fold 5 - PAUC: 0.15564429331042334
# Trial 22 finished with value: 0.16311777083135212 and parameters: {'min_child_samples': 221, 'n_estimators': 7200, 'learning_rate': 0.0023362770791702167, 'reg_alpha': 1.0446777372037108, 'reg_lambda': 0.7586568118632194, 'num_leaves': 155, 'max_depth': 125, 'subsample': 0.5316357400870356, 'colsample_bytree': 0.49634853732098433, 'pos_class_weight': 987.1403292959459}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:21:11,843] Trial 22 finished with value: 0.16311777083135212 and parameters: {'min_child_samples': 221, 'n_estimators': 7200, 'learning_rate': 0.0023362770791702167, 'reg_alpha': 1.0446777372037108, 'reg_lambda': 0.7586568118632194, 'num_leaves': 155, 'max_depth': 125, 'subsample': 0.5316357400870356, 'colsample_bytree': 0.49634853732098433, 'pos_class_weight': 987.1403292959459}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1670779042506399
# Fold 2 - PAUC: 0.14637460402803226
# Fold 3 - PAUC: 0.17591977696054664
# Fold 4 - PAUC: 0.15546768881350137
# Fold 5 - PAUC: 0.15713985888071466
# Trial 23 finished with value: 0.16039596658668698 and parameters: {'min_child_samples': 143, 'n_estimators': 7500, 'learning_rate': 0.0004962503856292955, 'reg_alpha': 0.7955110174517759, 'reg_lambda': 1.9175732291095202, 'num_leaves': 139, 'max_depth': 112, 'subsample': 0.648391725041621, 'colsample_bytree': 0.40366334100027373, 'pos_class_weight': 1031.7829773142141}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:39:54,286] Trial 23 finished with value: 0.16039596658668698 and parameters: {'min_child_samples': 143, 'n_estimators': 7500, 'learning_rate': 0.0004962503856292955, 'reg_alpha': 0.7955110174517759, 'reg_lambda': 1.9175732291095202, 'num_leaves': 139, 'max_depth': 112, 'subsample': 0.648391725041621, 'colsample_bytree': 0.40366334100027373, 'pos_class_weight': 1031.7829773142141}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1630391172707792
# Fold 2 - PAUC: 0.1420648112272383
# Fold 3 - PAUC: 0.17313267974044427
# Fold 4 - PAUC: 0.15210091428128936
# Fold 5 - PAUC: 0.15532531063211302
# Trial 24 finished with value: 0.15713256663037284 and parameters: {'min_child_samples': 247, 'n_estimators': 400, 'learning_rate': 0.0024605221551059655, 'reg_alpha': 1.8180818184035976, 'reg_lambda': 0.40623299479382646, 'num_leaves': 109, 'max_depth': 114, 'subsample': 0.7473749762223546, 'colsample_bytree': 0.5832777328559585, 'pos_class_weight': 1094.2339544648405}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:40:49,308] Trial 24 finished with value: 0.15713256663037284 and parameters: {'min_child_samples': 247, 'n_estimators': 400, 'learning_rate': 0.0024605221551059655, 'reg_alpha': 1.8180818184035976, 'reg_lambda': 0.40623299479382646, 'num_leaves': 109, 'max_depth': 114, 'subsample': 0.7473749762223546, 'colsample_bytree': 0.5832777328559585, 'pos_class_weight': 1094.2339544648405}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.16542667655054405
# Fold 2 - PAUC: 0.14573954535524447
# Fold 3 - PAUC: 0.17376153810955947
# Fold 4 - PAUC: 0.14945723247920842
# Fold 5 - PAUC: 0.1592885593933851
# Trial 25 finished with value: 0.1587347103775883 and parameters: {'min_child_samples': 159, 'n_estimators': 6000, 'learning_rate': 0.0004049117131593305, 'reg_alpha': 0.19748849247672162, 'reg_lambda': 0.039223728840260055, 'num_leaves': 187, 'max_depth': 126, 'subsample': 0.6049293512900917, 'colsample_bytree': 0.46149752707366976, 'pos_class_weight': 915.3164134569339}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 19:57:24,760] Trial 25 finished with value: 0.1587347103775883 and parameters: {'min_child_samples': 159, 'n_estimators': 6000, 'learning_rate': 0.0004049117131593305, 'reg_alpha': 0.19748849247672162, 'reg_lambda': 0.039223728840260055, 'num_leaves': 187, 'max_depth': 126, 'subsample': 0.6049293512900917, 'colsample_bytree': 0.46149752707366976, 'pos_class_weight': 915.3164134569339}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.15750021311705487
# Fold 2 - PAUC: 0.15123213079941342
# Fold 3 - PAUC: 0.16836592498304898
# Fold 4 - PAUC: 0.15479169726483563
# Fold 5 - PAUC: 0.15822837389982006
# Trial 26 finished with value: 0.15802366801283457 and parameters: {'min_child_samples': 67, 'n_estimators': 8100, 'learning_rate': 0.0010637061197697397, 'reg_alpha': 0.037591113492050715, 'reg_lambda': 0.18603894412357286, 'num_leaves': 145, 'max_depth': 107, 'subsample': 0.40230710564947547, 'colsample_bytree': 0.664291879275543, 'pos_class_weight': 485.5242514216393}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 20:18:33,543] Trial 26 finished with value: 0.15802366801283457 and parameters: {'min_child_samples': 67, 'n_estimators': 8100, 'learning_rate': 0.0010637061197697397, 'reg_alpha': 0.037591113492050715, 'reg_lambda': 0.18603894412357286, 'num_leaves': 145, 'max_depth': 107, 'subsample': 0.40230710564947547, 'colsample_bytree': 0.664291879275543, 'pos_class_weight': 485.5242514216393}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.16548592795379424
# Fold 2 - PAUC: 0.1598875604247697
# Fold 3 - PAUC: 0.16963548101281614
# Fold 4 - PAUC: 0.15652887331222096
# Fold 5 - PAUC: 0.15502029823470423
# Trial 27 finished with value: 0.16131162818766104 and parameters: {'min_child_samples': 284, 'n_estimators': 9100, 'learning_rate': 0.016685325808384898, 'reg_alpha': 0.012840581475219163, 'reg_lambda': 9.294738822891839, 'num_leaves': 121, 'max_depth': 82, 'subsample': 0.6740205551605984, 'colsample_bytree': 0.5572608536448276, 'pos_class_weight': 684.423772351884}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 20:20:30,007] Trial 27 finished with value: 0.16131162818766104 and parameters: {'min_child_samples': 284, 'n_estimators': 9100, 'learning_rate': 0.016685325808384898, 'reg_alpha': 0.012840581475219163, 'reg_lambda': 9.294738822891839, 'num_leaves': 121, 'max_depth': 82, 'subsample': 0.6740205551605984, 'colsample_bytree': 0.5572608536448276, 'pos_class_weight': 684.423772351884}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.17036023102861145
# Fold 2 - PAUC: 0.15811803238561672
# Fold 3 - PAUC: 0.17526669604090886
# Fold 4 - PAUC: 0.15837596278238708
# Fold 5 - PAUC: 0.1600456124809387
# Trial 28 finished with value: 0.16443330694369257 and parameters: {'min_child_samples': 209, 'n_estimators': 6500, 'learning_rate': 0.006132325536904858, 'reg_alpha': 0.14570324608696483, 'reg_lambda': 0.793671365866666, 'num_leaves': 170, 'max_depth': 118, 'subsample': 0.6117160161830096, 'colsample_bytree': 0.5043324261935147, 'pos_class_weight': 1081.443991480424}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 20:24:30,069] Trial 28 finished with value: 0.16443330694369257 and parameters: {'min_child_samples': 209, 'n_estimators': 6500, 'learning_rate': 0.006132325536904858, 'reg_alpha': 0.14570324608696483, 'reg_lambda': 0.793671365866666, 'num_leaves': 170, 'max_depth': 118, 'subsample': 0.6117160161830096, 'colsample_bytree': 0.5043324261935147, 'pos_class_weight': 1081.443991480424}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.1703623378892303
# Fold 2 - PAUC: 0.16061571733378793
# Fold 3 - PAUC: 0.17491631700759022
# Fold 4 - PAUC: 0.15937532698043344
# Fold 5 - PAUC: 0.15729606023492435
# Trial 29 finished with value: 0.16451315188919327 and parameters: {'min_child_samples': 370, 'n_estimators': 6700, 'learning_rate': 0.007546810080611566, 'reg_alpha': 0.11824250909893994, 'reg_lambda': 2.7191011729623096, 'num_leaves': 180, 'max_depth': 49, 'subsample': 0.5577287167367972, 'colsample_bytree': 0.43481590127528685, 'pos_class_weight': 941.0800373995847}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 20:28:05,439] Trial 29 finished with value: 0.16451315188919327 and parameters: {'min_child_samples': 370, 'n_estimators': 6700, 'learning_rate': 0.007546810080611566, 'reg_alpha': 0.11824250909893994, 'reg_lambda': 2.7191011729623096, 'num_leaves': 180, 'max_depth': 49, 'subsample': 0.5577287167367972, 'colsample_bytree': 0.43481590127528685, 'pos_class_weight': 941.0800373995847}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.16805950681958362
# Fold 2 - PAUC: 0.15571609187677293
# Fold 3 - PAUC: 0.16431771922768135
# Fold 4 - PAUC: 0.15726687715007132
# Fold 5 - PAUC: 0.1670447556262389
# Trial 30 finished with value: 0.16248099014006961 and parameters: {'min_child_samples': 350, 'n_estimators': 3600, 'learning_rate': 0.005007548807589731, 'reg_alpha': 0.1147532146646378, 'reg_lambda': 3.3365459702495786, 'num_leaves': 256, 'max_depth': 2, 'subsample': 0.5621718426207886, 'colsample_bytree': 0.6358330224200326, 'pos_class_weight': 937.9313002741906}. Best is trial 15 with value: 0.16466886584132912.
# [I 2024-08-01 20:29:30,699] Trial 30 finished with value: 0.16248099014006961 and parameters: {'min_child_samples': 350, 'n_estimators': 3600, 'learning_rate': 0.005007548807589731, 'reg_alpha': 0.1147532146646378, 'reg_lambda': 3.3365459702495786, 'num_leaves': 256, 'max_depth': 2, 'subsample': 0.5621718426207886, 'colsample_bytree': 0.6358330224200326, 'pos_class_weight': 937.9313002741906}. Best is trial 15 with value: 0.16466886584132912.
# Fold 1 - PAUC: 0.174487733047146
# Fold 2 - PAUC: 0.1592055316470103
# Fold 3 - PAUC: 0.17417300148759093
# Fold 4 - PAUC: 0.1581505042738242
# Fold 5 - PAUC: 0.15907044797763975
# Trial 31 finished with value: 0.16501744368664223 and parameters: {'min_child_samples': 467, 'n_estimators': 5600, 'learning_rate': 0.006714996237833257, 'reg_alpha': 0.022350505877548416, 'reg_lambda': 0.4184617676722456, 'num_leaves': 177, 'max_depth': 53, 'subsample': 0.48163583923858067, 'colsample_bytree': 0.4563048015090839, 'pos_class_weight': 1129.974793334261}. Best is trial 31 with value: 0.16501744368664223.
# [I 2024-08-01 20:33:16,860] Trial 31 finished with value: 0.16501744368664223 and parameters: {'min_child_samples': 467, 'n_estimators': 5600, 'learning_rate': 0.006714996237833257, 'reg_alpha': 0.022350505877548416, 'reg_lambda': 0.4184617676722456, 'num_leaves': 177, 'max_depth': 53, 'subsample': 0.48163583923858067, 'colsample_bytree': 0.4563048015090839, 'pos_class_weight': 1129.974793334261}. Best is trial 31 with value: 0.16501744368664223.
# Fold 1 - PAUC: 0.17470934237100905
# Fold 2 - PAUC: 0.15716795526232816
# Fold 3 - PAUC: 0.17270092957637412
# Fold 4 - PAUC: 0.15963092768528728
# Fold 5 - PAUC: 0.16228497395806737
# Trial 32 finished with value: 0.1652988257706132 and parameters: {'min_child_samples': 472, 'n_estimators': 5500, 'learning_rate': 0.007191948403256978, 'reg_alpha': 0.018041381532592243, 'reg_lambda': 0.12736969919094032, 'num_leaves': 175, 'max_depth': 50, 'subsample': 0.48658497585410265, 'colsample_bytree': 0.4561278092922128, 'pos_class_weight': 1122.8650646332799}. Best is trial 32 with value: 0.1652988257706132.
# [I 2024-08-01 20:36:50,750] Trial 32 finished with value: 0.1652988257706132 and parameters: {'min_child_samples': 472, 'n_estimators': 5500, 'learning_rate': 0.007191948403256978, 'reg_alpha': 0.018041381532592243, 'reg_lambda': 0.12736969919094032, 'num_leaves': 175, 'max_depth': 50, 'subsample': 0.48658497585410265, 'colsample_bytree': 0.4561278092922128, 'pos_class_weight': 1122.8650646332799}. Best is trial 32 with value: 0.1652988257706132.
# Fold 1 - PAUC: 0.17298495798757854
# Fold 2 - PAUC: 0.15371294620284132
# Fold 3 - PAUC: 0.1731673976629238
# Fold 4 - PAUC: 0.15799627350299356
# Fold 5 - PAUC: 0.16114576399852126
# Trial 33 finished with value: 0.1638014678709717 and parameters: {'min_child_samples': 482, 'n_estimators': 5400, 'learning_rate': 0.020360276165745327, 'reg_alpha': 0.015563134103697685, 'reg_lambda': 0.03085961168828599, 'num_leaves': 188, 'max_depth': 51, 'subsample': 0.47255405543697077, 'colsample_bytree': 0.4485525855669008, 'pos_class_weight': 1134.386987521671}. Best is trial 32 with value: 0.1652988257706132.
# [I 2024-08-01 20:38:18,780] Trial 33 finished with value: 0.1638014678709717 and parameters: {'min_child_samples': 482, 'n_estimators': 5400, 'learning_rate': 0.020360276165745327, 'reg_alpha': 0.015563134103697685, 'reg_lambda': 0.03085961168828599, 'num_leaves': 188, 'max_depth': 51, 'subsample': 0.47255405543697077, 'colsample_bytree': 0.4485525855669008, 'pos_class_weight': 1134.386987521671}. Best is trial 32 with value: 0.1652988257706132.
# Fold 1 - PAUC: 0.1732099382884318
# Fold 2 - PAUC: 0.1559244503001711
# Fold 3 - PAUC: 0.17345179664448876
# Fold 4 - PAUC: 0.1574738727634538
# Fold 5 - PAUC: 0.16258771740034136
# Trial 34 finished with value: 0.16452955507937736 and parameters: {'min_child_samples': 437, 'n_estimators': 9600, 'learning_rate': 0.00860241604413347, 'reg_alpha': 0.020460673341803234, 'reg_lambda': 0.1264508456382506, 'num_leaves': 209, 'max_depth': 46, 'subsample': 0.4874573337741204, 'colsample_bytree': 0.47556702762350966, 'pos_class_weight': 1199.7844022220272}. Best is trial 32 with value: 0.1652988257706132.
# [I 2024-08-01 20:41:22,883] Trial 34 finished with value: 0.16452955507937736 and parameters: {'min_child_samples': 437, 'n_estimators': 9600, 'learning_rate': 0.00860241604413347, 'reg_alpha': 0.020460673341803234, 'reg_lambda': 0.1264508456382506, 'num_leaves': 209, 'max_depth': 46, 'subsample': 0.4874573337741204, 'colsample_bytree': 0.47556702762350966, 'pos_class_weight': 1199.7844022220272}. Best is trial 32 with value: 0.1652988257706132.
# Fold 1 - PAUC: 0.17394908982000598
# Fold 2 - PAUC: 0.155139580447506
# Fold 3 - PAUC: 0.1697116684537597
# Fold 4 - PAUC: 0.15768010042279065
# Fold 5 - PAUC: 0.1623612108505972
# Trial 35 finished with value: 0.16376832999893193 and parameters: {'min_child_samples': 440, 'n_estimators': 10000, 'learning_rate': 0.00146856979835357, 'reg_alpha': 0.004570720871950988, 'reg_lambda': 0.09931710431464962, 'num_leaves': 212, 'max_depth': 31, 'subsample': 0.4000496492648109, 'colsample_bytree': 0.5678898196913974, 'pos_class_weight': 1192.783619201194}. Best is trial 32 with value: 0.1652988257706132.
# [I 2024-08-01 21:01:25,286] Trial 35 finished with value: 0.16376832999893193 and parameters: {'min_child_samples': 440, 'n_estimators': 10000, 'learning_rate': 0.00146856979835357, 'reg_alpha': 0.004570720871950988, 'reg_lambda': 0.09931710431464962, 'num_leaves': 212, 'max_depth': 31, 'subsample': 0.4000496492648109, 'colsample_bytree': 0.5678898196913974, 'pos_class_weight': 1192.783619201194}. Best is trial 32 with value: 0.1652988257706132.
# Fold 1 - PAUC: 0.17483893050568863
# Fold 2 - PAUC: 0.15822724840434702
# Fold 3 - PAUC: 0.1720063471401871
# Fold 4 - PAUC: 0.1596568461343273
# Fold 5 - PAUC: 0.1620613846363537
# Trial 36 finished with value: 0.16535815136418072 and parameters: {'min_child_samples': 439, 'n_estimators': 9800, 'learning_rate': 0.0038414458596793552, 'reg_alpha': 0.007345270818809884, 'reg_lambda': 0.27680721612417547, 'num_leaves': 218, 'max_depth': 32, 'subsample': 0.477904811961798, 'colsample_bytree': 0.4851734117427794, 'pos_class_weight': 1122.7258148077033}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 21:08:03,318] Trial 36 finished with value: 0.16535815136418072 and parameters: {'min_child_samples': 439, 'n_estimators': 9800, 'learning_rate': 0.0038414458596793552, 'reg_alpha': 0.007345270818809884, 'reg_lambda': 0.27680721612417547, 'num_leaves': 218, 'max_depth': 32, 'subsample': 0.477904811961798, 'colsample_bytree': 0.4851734117427794, 'pos_class_weight': 1122.7258148077033}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.17402545541412934
# Fold 2 - PAUC: 0.15838211142650038
# Fold 3 - PAUC: 0.16610973999315878
# Fold 4 - PAUC: 0.15829609556164154
# Fold 5 - PAUC: 0.15682528445809485
# Trial 37 finished with value: 0.16272773737070495 and parameters: {'min_child_samples': 491, 'n_estimators': 9400, 'learning_rate': 0.0037627897741258735, 'reg_alpha': 0.007571840157584768, 'reg_lambda': 0.3856944508640282, 'num_leaves': 223, 'max_depth': 30, 'subsample': 0.4434194881913436, 'colsample_bytree': 0.7096563245222456, 'pos_class_weight': 1118.5480612906767}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 21:15:14,145] Trial 37 finished with value: 0.16272773737070495 and parameters: {'min_child_samples': 491, 'n_estimators': 9400, 'learning_rate': 0.0037627897741258735, 'reg_alpha': 0.007571840157584768, 'reg_lambda': 0.3856944508640282, 'num_leaves': 223, 'max_depth': 30, 'subsample': 0.4434194881913436, 'colsample_bytree': 0.7096563245222456, 'pos_class_weight': 1118.5480612906767}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.15498987248307136
# Fold 2 - PAUC: 0.1365079350760084
# Fold 3 - PAUC: 0.1648379760955104
# Fold 4 - PAUC: 0.15116353037434238
# Fold 5 - PAUC: 0.12975930761861648
# Trial 38 finished with value: 0.1474517243295098 and parameters: {'min_child_samples': 459, 'n_estimators': 5200, 'learning_rate': 0.0007425685249600545, 'reg_alpha': 0.0010934455904936776, 'reg_lambda': 0.2963959347764281, 'num_leaves': 198, 'max_depth': 37, 'subsample': 0.49105094685105194, 'colsample_bytree': 0.8354467069954556, 'pos_class_weight': 999.8723356699933}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 21:28:38,932] Trial 38 finished with value: 0.1474517243295098 and parameters: {'min_child_samples': 459, 'n_estimators': 5200, 'learning_rate': 0.0007425685249600545, 'reg_alpha': 0.0010934455904936776, 'reg_lambda': 0.2963959347764281, 'num_leaves': 198, 'max_depth': 37, 'subsample': 0.49105094685105194, 'colsample_bytree': 0.8354467069954556, 'pos_class_weight': 999.8723356699933}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.16604914041707408
# Fold 2 - PAUC: 0.14966891639035643
# Fold 3 - PAUC: 0.17539155256949418
# Fold 4 - PAUC: 0.15885279824855278
# Fold 5 - PAUC: 0.15826425580459494
# Trial 39 finished with value: 0.16164533268601447 and parameters: {'min_child_samples': 407, 'n_estimators': 2800, 'learning_rate': 0.001756917184223001, 'reg_alpha': 0.007745718526627606, 'reg_lambda': 0.07602292014394836, 'num_leaves': 251, 'max_depth': 24, 'subsample': 0.43059168931237174, 'colsample_bytree': 0.4342727928213039, 'pos_class_weight': 866.8830338933233}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 21:35:34,000] Trial 39 finished with value: 0.16164533268601447 and parameters: {'min_child_samples': 407, 'n_estimators': 2800, 'learning_rate': 0.001756917184223001, 'reg_alpha': 0.007745718526627606, 'reg_lambda': 0.07602292014394836, 'num_leaves': 251, 'max_depth': 24, 'subsample': 0.43059168931237174, 'colsample_bytree': 0.4342727928213039, 'pos_class_weight': 866.8830338933233}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.16514526479834582
# Fold 2 - PAUC: 0.14514457064527808
# Fold 3 - PAUC: 0.17426131620283838
# Fold 4 - PAUC: 0.15110999757774493
# Fold 5 - PAUC: 0.15814322325497496
# Trial 40 finished with value: 0.15876087449583642 and parameters: {'min_child_samples': 332, 'n_estimators': 8000, 'learning_rate': 0.0003189873414410655, 'reg_alpha': 0.04187036366533858, 'reg_lambda': 0.17370234060659842, 'num_leaves': 172, 'max_depth': 62, 'subsample': 0.5351070625692315, 'colsample_bytree': 0.49030301826359374, 'pos_class_weight': 1117.4582832611968}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 21:55:04,883] Trial 40 finished with value: 0.15876087449583642 and parameters: {'min_child_samples': 332, 'n_estimators': 8000, 'learning_rate': 0.0003189873414410655, 'reg_alpha': 0.04187036366533858, 'reg_lambda': 0.17370234060659842, 'num_leaves': 172, 'max_depth': 62, 'subsample': 0.5351070625692315, 'colsample_bytree': 0.49030301826359374, 'pos_class_weight': 1117.4582832611968}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.1732362578395473
# Fold 2 - PAUC: 0.15635662337869313
# Fold 3 - PAUC: 0.17369082234119104
# Fold 4 - PAUC: 0.1564938354088891
# Fold 5 - PAUC: 0.16332629471036864
# Trial 41 finished with value: 0.16462076673573783 and parameters: {'min_child_samples': 399, 'n_estimators': 9100, 'learning_rate': 0.003978974419645138, 'reg_alpha': 0.004830568675915343, 'reg_lambda': 0.0058840478966702804, 'num_leaves': 222, 'max_depth': 42, 'subsample': 0.4742084621409273, 'colsample_bytree': 0.4001744862629074, 'pos_class_weight': 760.3169919326357}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 22:02:02,042] Trial 41 finished with value: 0.16462076673573783 and parameters: {'min_child_samples': 399, 'n_estimators': 9100, 'learning_rate': 0.003978974419645138, 'reg_alpha': 0.004830568675915343, 'reg_lambda': 0.0058840478966702804, 'num_leaves': 222, 'max_depth': 42, 'subsample': 0.4742084621409273, 'colsample_bytree': 0.4001744862629074, 'pos_class_weight': 760.3169919326357}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.17346175675224515
# Fold 2 - PAUC: 0.15596790215784326
# Fold 3 - PAUC: 0.1731627579405648
# Fold 4 - PAUC: 0.1559781542672486
# Fold 5 - PAUC: 0.16258411948577045
# Trial 42 finished with value: 0.16423093812073447 and parameters: {'min_child_samples': 404, 'n_estimators': 10000, 'learning_rate': 0.004027678983956209, 'reg_alpha': 0.003260823038002428, 'reg_lambda': 0.005541087107399077, 'num_leaves': 226, 'max_depth': 41, 'subsample': 0.4518570458901308, 'colsample_bytree': 0.44870834779593044, 'pos_class_weight': 766.9939380491415}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 22:09:16,467] Trial 42 finished with value: 0.16423093812073447 and parameters: {'min_child_samples': 404, 'n_estimators': 10000, 'learning_rate': 0.004027678983956209, 'reg_alpha': 0.003260823038002428, 'reg_lambda': 0.005541087107399077, 'num_leaves': 226, 'max_depth': 41, 'subsample': 0.4518570458901308, 'colsample_bytree': 0.44870834779593044, 'pos_class_weight': 766.9939380491415}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.17534658667511133
# Fold 2 - PAUC: 0.15636946347781147
# Fold 3 - PAUC: 0.16711751968762187
# Fold 4 - PAUC: 0.15519637704879735
# Fold 5 - PAUC: 0.1640599127327441
# Trial 43 finished with value: 0.16361797192441724 and parameters: {'min_child_samples': 465, 'n_estimators': 9100, 'learning_rate': 0.010851893192319223, 'reg_alpha': 0.005698896727130246, 'reg_lambda': 0.0030448637788760735, 'num_leaves': 244, 'max_depth': 18, 'subsample': 0.48091887328208033, 'colsample_bytree': 0.4214750920268831, 'pos_class_weight': 973.199635891318}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 22:12:03,717] Trial 43 finished with value: 0.16361797192441724 and parameters: {'min_child_samples': 465, 'n_estimators': 9100, 'learning_rate': 0.010851893192319223, 'reg_alpha': 0.005698896727130246, 'reg_lambda': 0.0030448637788760735, 'num_leaves': 244, 'max_depth': 18, 'subsample': 0.48091887328208033, 'colsample_bytree': 0.4214750920268831, 'pos_class_weight': 973.199635891318}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.17161368344386785
# Fold 2 - PAUC: 0.14899296185152422
# Fold 3 - PAUC: 0.16818862359276418
# Fold 4 - PAUC: 0.15745112212485202
# Fold 5 - PAUC: 0.1626073924827247
# Trial 44 finished with value: 0.1617707566991466 and parameters: {'min_child_samples': 417, 'n_estimators': 9100, 'learning_rate': 0.02042487410095585, 'reg_alpha': 0.022816887281253785, 'reg_lambda': 0.022346869485476498, 'num_leaves': 200, 'max_depth': 35, 'subsample': 0.5407123812637318, 'colsample_bytree': 0.4021790446922809, 'pos_class_weight': 1150.888462852843}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 22:13:29,467] Trial 44 finished with value: 0.1617707566991466 and parameters: {'min_child_samples': 417, 'n_estimators': 9100, 'learning_rate': 0.02042487410095585, 'reg_alpha': 0.022816887281253785, 'reg_lambda': 0.022346869485476498, 'num_leaves': 200, 'max_depth': 35, 'subsample': 0.5407123812637318, 'colsample_bytree': 0.4021790446922809, 'pos_class_weight': 1150.888462852843}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.17412859434473227
# Fold 2 - PAUC: 0.15738434250648656
# Fold 3 - PAUC: 0.17272531211732284
# Fold 4 - PAUC: 0.15875354018815507
# Fold 5 - PAUC: 0.1624667820916557
# Trial 45 finished with value: 0.16509171424967048 and parameters: {'min_child_samples': 497, 'n_estimators': 5400, 'learning_rate': 0.0018102560708172701, 'reg_alpha': 0.002133759151787548, 'reg_lambda': 0.008126147177588148, 'num_leaves': 218, 'max_depth': 45, 'subsample': 0.5083364837165902, 'colsample_bytree': 0.46500835915695576, 'pos_class_weight': 1057.2590908462591}. Best is trial 36 with value: 0.16535815136418072.
# [I 2024-08-01 22:31:32,673] Trial 45 finished with value: 0.16509171424967048 and parameters: {'min_child_samples': 497, 'n_estimators': 5400, 'learning_rate': 0.0018102560708172701, 'reg_alpha': 0.002133759151787548, 'reg_lambda': 0.008126147177588148, 'num_leaves': 218, 'max_depth': 45, 'subsample': 0.5083364837165902, 'colsample_bytree': 0.46500835915695576, 'pos_class_weight': 1057.2590908462591}. Best is trial 36 with value: 0.16535815136418072.
# Fold 1 - PAUC: 0.1654261579386994
# Fold 2 - PAUC: 0.14826161747059366
# Fold 3 - PAUC: 0.1750802751963322
# Fold 4 - PAUC: 0.15741496428853693
# Fold 5 - PAUC: 0.15780735306773264
# Trial 46 finished with value: 0.16079807359237897 and parameters: {'min_child_samples': 462, 'n_estimators': 5600, 'learning_rate': 0.0008553815011292984, 'reg_alpha': 0.002100349617092614, 'reg_lambda': 0.05315063979212658, 'num_leaves': 162, 'max_depth': 54, 'subsample': 0.506497602254404, 'colsample_bytree': 0.5449148503141834, 'pos_class_weight': 1064.430827488985}. Best is trial 36 with value: 0.16535815136418072.
# ...
# Fold 1 - PAUC: 0.16552712518220286
# Fold 2 - PAUC: 0.1421790189472652
# Fold 3 - PAUC: 0.17292389223428864
# Fold 4 - PAUC: 0.15341709152124333
# Fold 5 - PAUC: 0.15783662258897177
# Trial 86 finished with value: 0.15837675009479435 and parameters: {'min_child_samples': 443, 'n_estimators': 1500, 'learning_rate': 0.0021236442438627417, 'reg_alpha': 0.002549709373031481, 'reg_lambda': 0.8877493049042642, 'num_leaves': 176, 'max_depth': 43, 'subsample': 0.6579808129139807, 'colsample_bytree': 0.49391406615790495, 'pos_class_weight': 607.6872643711968}. Best is trial 53 with value: 0.16542963895332052.
# [I 2024-08-02 04:31:21,772] Trial 86 finished with value: 0.15837675009479435 and parameters: {'min_child_samples': 443, 'n_estimators': 1500, 'learning_rate': 0.0021236442438627417, 'reg_alpha': 0.002549709373031481, 'reg_lambda': 0.8877493049042642, 'num_leaves': 176, 'max_depth': 43, 'subsample': 0.6579808129139807, 'colsample_bytree': 0.49391406615790495, 'pos_class_weight': 607.6872643711968}. Best is trial 53 with value: 0.16542963895332052.
# Fold 1 - PAUC: 0.17541202900725697
# Fold 2 - PAUC: 0.15703203664871002
# Fold 3 - PAUC: 0.17003596904761215
# Fold 4 - PAUC: 0.15821910816856713
# Fold 5 - PAUC: 0.16152007676847627
# Trial 87 finished with value: 0.1644438439281245 and parameters: {'min_child_samples': 471, 'n_estimators': 7700, 'learning_rate': 0.003049865511019095, 'reg_alpha': 0.007642369176168904, 'reg_lambda': 0.14139427539553795, 'num_leaves': 125, 'max_depth': 62, 'subsample': 0.43684915737848135, 'colsample_bytree': 0.5355803858343668, 'pos_class_weight': 313.94702592961863}. Best is trial 53 with value: 0.16542963895332052.
# [I 2024-08-02 04:37:47,245] Trial 87 finished with value: 0.1644438439281245 and parameters: {'min_child_samples': 471, 'n_estimators': 7700, 'learning_rate': 0.003049865511019095, 'reg_alpha': 0.007642369176168904, 'reg_lambda': 0.14139427539553795, 'num_leaves': 125, 'max_depth': 62, 'subsample': 0.43684915737848135, 'colsample_bytree': 0.5355803858343668, 'pos_class_weight': 313.94702592961863}. Best is trial 53 with value: 0.16542963895332052.
# Fold 1 - PAUC: 0.1734013060591042
# Fold 2 - PAUC: 0.15793219675903267
# Fold 3 - PAUC: 0.1744213386270965
# Fold 4 - PAUC: 0.16003826331032348
# Fold 5 - PAUC: 0.16281153361756853
# Trial 88 finished with value: 0.16572092767462507 and parameters: {'min_child_samples': 485, 'n_estimators': 8400, 'learning_rate': 0.007512103292915293, 'reg_alpha': 0.0027291905128624325, 'reg_lambda': 0.23105994775417862, 'num_leaves': 191, 'max_depth': 39, 'subsample': 0.45990831207544924, 'colsample_bytree': 0.4649846963529439, 'pos_class_weight': 545.918879501255}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:40:42,734] Trial 88 finished with value: 0.16572092767462507 and parameters: {'min_child_samples': 485, 'n_estimators': 8400, 'learning_rate': 0.007512103292915293, 'reg_alpha': 0.0027291905128624325, 'reg_lambda': 0.23105994775417862, 'num_leaves': 191, 'max_depth': 39, 'subsample': 0.45990831207544924, 'colsample_bytree': 0.4649846963529439, 'pos_class_weight': 545.918879501255}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.1748235018033106
# Fold 2 - PAUC: 0.15691394983550688
# Fold 3 - PAUC: 0.17359114830568534
# Fold 4 - PAUC: 0.15820976472767867
# Fold 5 - PAUC: 0.16305933593193522
# Trial 89 finished with value: 0.16531954012082334 and parameters: {'min_child_samples': 485, 'n_estimators': 8200, 'learning_rate': 0.008076679107152896, 'reg_alpha': 0.0026703565975691743, 'reg_lambda': 0.08528770976374955, 'num_leaves': 145, 'max_depth': 40, 'subsample': 0.4603789862199023, 'colsample_bytree': 0.4172091334544774, 'pos_class_weight': 1107.6266674505666}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:43:32,032] Trial 89 finished with value: 0.16531954012082334 and parameters: {'min_child_samples': 485, 'n_estimators': 8200, 'learning_rate': 0.008076679107152896, 'reg_alpha': 0.0026703565975691743, 'reg_lambda': 0.08528770976374955, 'num_leaves': 145, 'max_depth': 40, 'subsample': 0.4603789862199023, 'colsample_bytree': 0.4172091334544774, 'pos_class_weight': 1107.6266674505666}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.1725898081752026
# Fold 2 - PAUC: 0.156965911641775
# Fold 3 - PAUC: 0.17376278603488365
# Fold 4 - PAUC: 0.15866704936376605
# Fold 5 - PAUC: 0.16185559040562594
# Trial 90 finished with value: 0.16476822912425065 and parameters: {'min_child_samples': 454, 'n_estimators': 8800, 'learning_rate': 0.007342307601821818, 'reg_alpha': 0.0010221593828412248, 'reg_lambda': 0.07990359867992274, 'num_leaves': 145, 'max_depth': 47, 'subsample': 0.5204797334901508, 'colsample_bytree': 0.4328886048478769, 'pos_class_weight': 1125.2609074900909}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:46:37,064] Trial 90 finished with value: 0.16476822912425065 and parameters: {'min_child_samples': 454, 'n_estimators': 8800, 'learning_rate': 0.007342307601821818, 'reg_alpha': 0.0010221593828412248, 'reg_lambda': 0.07990359867992274, 'num_leaves': 145, 'max_depth': 47, 'subsample': 0.5204797334901508, 'colsample_bytree': 0.4328886048478769, 'pos_class_weight': 1125.2609074900909}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17459748427876812
# Fold 2 - PAUC: 0.1547868235323834
# Fold 3 - PAUC: 0.17342507824331788
# Fold 4 - PAUC: 0.15775014423136918
# Fold 5 - PAUC: 0.15985417749484981
# Trial 91 finished with value: 0.16408274155613767 and parameters: {'min_child_samples': 432, 'n_estimators': 9900, 'learning_rate': 0.009420584264222412, 'reg_alpha': 0.0025570265389438795, 'reg_lambda': 0.22102595121408067, 'num_leaves': 229, 'max_depth': 35, 'subsample': 0.4613687537023971, 'colsample_bytree': 0.42033417570892617, 'pos_class_weight': 1021.4473306358733}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:49:09,119] Trial 91 finished with value: 0.16408274155613767 and parameters: {'min_child_samples': 432, 'n_estimators': 9900, 'learning_rate': 0.009420584264222412, 'reg_alpha': 0.0025570265389438795, 'reg_lambda': 0.22102595121408067, 'num_leaves': 229, 'max_depth': 35, 'subsample': 0.4613687537023971, 'colsample_bytree': 0.42033417570892617, 'pos_class_weight': 1021.4473306358733}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17535099487579078
# Fold 2 - PAUC: 0.15639312895323568
# Fold 3 - PAUC: 0.17162582591057748
# Fold 4 - PAUC: 0.15801864016457254
# Fold 5 - PAUC: 0.1595475444152019
# Trial 92 finished with value: 0.16418722686387568 and parameters: {'min_child_samples': 479, 'n_estimators': 8100, 'learning_rate': 0.00478526010720981, 'reg_alpha': 0.0033005697916438114, 'reg_lambda': 0.14512048638682165, 'num_leaves': 133, 'max_depth': 41, 'subsample': 0.49263581896314024, 'colsample_bytree': 0.46772321093346636, 'pos_class_weight': 1064.350257546692}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:53:43,981] Trial 92 finished with value: 0.16418722686387568 and parameters: {'min_child_samples': 479, 'n_estimators': 8100, 'learning_rate': 0.00478526010720981, 'reg_alpha': 0.0033005697916438114, 'reg_lambda': 0.14512048638682165, 'num_leaves': 133, 'max_depth': 41, 'subsample': 0.49263581896314024, 'colsample_bytree': 0.46772321093346636, 'pos_class_weight': 1064.350257546692}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17354654978884393
# Fold 2 - PAUC: 0.15878689028887058
# Fold 3 - PAUC: 0.17169558173638888
# Fold 4 - PAUC: 0.15627781633547047
# Fold 5 - PAUC: 0.16035211590600754
# Trial 93 finished with value: 0.16413179081111626 and parameters: {'min_child_samples': 491, 'n_estimators': 5500, 'learning_rate': 0.012331991673605328, 'reg_alpha': 0.004261427556374251, 'reg_lambda': 0.3310165574819199, 'num_leaves': 150, 'max_depth': 38, 'subsample': 0.4129426674215159, 'colsample_bytree': 0.4502777183961521, 'pos_class_weight': 1170.216991283627}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:55:40,589] Trial 93 finished with value: 0.16413179081111626 and parameters: {'min_child_samples': 491, 'n_estimators': 5500, 'learning_rate': 0.012331991673605328, 'reg_alpha': 0.004261427556374251, 'reg_lambda': 0.3310165574819199, 'num_leaves': 150, 'max_depth': 38, 'subsample': 0.4129426674215159, 'colsample_bytree': 0.4502777183961521, 'pos_class_weight': 1170.216991283627}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17522707905816193
# Fold 2 - PAUC: 0.1586292006406818
# Fold 3 - PAUC: 0.17267645104116966
# Fold 4 - PAUC: 0.15933488140069693
# Fold 5 - PAUC: 0.1620064110948016
# Trial 94 finished with value: 0.1655748046471024 and parameters: {'min_child_samples': 461, 'n_estimators': 8500, 'learning_rate': 0.007348741614142114, 'reg_alpha': 0.0013994798639457566, 'reg_lambda': 0.40732173420514584, 'num_leaves': 189, 'max_depth': 52, 'subsample': 0.4782022419381297, 'colsample_bytree': 0.4153020471114723, 'pos_class_weight': 1108.8547950229033}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 04:58:51,741] Trial 94 finished with value: 0.1655748046471024 and parameters: {'min_child_samples': 461, 'n_estimators': 8500, 'learning_rate': 0.007348741614142114, 'reg_alpha': 0.0013994798639457566, 'reg_lambda': 0.40732173420514584, 'num_leaves': 189, 'max_depth': 52, 'subsample': 0.4782022419381297, 'colsample_bytree': 0.4153020471114723, 'pos_class_weight': 1108.8547950229033}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17425750180136576
# Fold 2 - PAUC: 0.15800938770619144
# Fold 3 - PAUC: 0.1726163586370991
# Fold 4 - PAUC: 0.15619506928705382
# Fold 5 - PAUC: 0.162636337867516
# Trial 95 finished with value: 0.16474293105984522 and parameters: {'min_child_samples': 498, 'n_estimators': 8500, 'learning_rate': 0.00642335311545507, 'reg_alpha': 0.0014651255882712289, 'reg_lambda': 0.05067866126494582, 'num_leaves': 190, 'max_depth': 52, 'subsample': 0.4630448996621029, 'colsample_bytree': 0.4143934586010822, 'pos_class_weight': 1102.9030041627616}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:02:47,274] Trial 95 finished with value: 0.16474293105984522 and parameters: {'min_child_samples': 498, 'n_estimators': 8500, 'learning_rate': 0.00642335311545507, 'reg_alpha': 0.0014651255882712289, 'reg_lambda': 0.05067866126494582, 'num_leaves': 190, 'max_depth': 52, 'subsample': 0.4630448996621029, 'colsample_bytree': 0.4143934586010822, 'pos_class_weight': 1102.9030041627616}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.1769235556417027
# Fold 2 - PAUC: 0.1533533332160584
# Fold 3 - PAUC: 0.17009798133679677
# Fold 4 - PAUC: 0.15877193908716497
# Fold 5 - PAUC: 0.16110761313861158
# Trial 96 finished with value: 0.16405088448406685 and parameters: {'min_child_samples': 463, 'n_estimators': 9200, 'learning_rate': 0.0178550703004674, 'reg_alpha': 0.0018629348065852319, 'reg_lambda': 0.10239165070315137, 'num_leaves': 196, 'max_depth': 61, 'subsample': 0.4828243678027865, 'colsample_bytree': 0.43943334246894267, 'pos_class_weight': 1183.0565785368683}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:04:15,606] Trial 96 finished with value: 0.16405088448406685 and parameters: {'min_child_samples': 463, 'n_estimators': 9200, 'learning_rate': 0.0178550703004674, 'reg_alpha': 0.0018629348065852319, 'reg_lambda': 0.10239165070315137, 'num_leaves': 196, 'max_depth': 61, 'subsample': 0.4828243678027865, 'colsample_bytree': 0.43943334246894267, 'pos_class_weight': 1183.0565785368683}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.16466830396747778
# Fold 2 - PAUC: 0.14285915328417104
# Fold 3 - PAUC: 0.17572942035148614
# Fold 4 - PAUC: 0.15022486654398598
# Fold 5 - PAUC: 0.15537477385405202
# Trial 97 finished with value: 0.1577713036002346 and parameters: {'min_child_samples': 420, 'n_estimators': 500, 'learning_rate': 0.003539197616917249, 'reg_alpha': 0.001152488809057357, 'reg_lambda': 0.17729358140391968, 'num_leaves': 216, 'max_depth': 45, 'subsample': 0.4454435662651652, 'colsample_bytree': 0.4193605606847936, 'pos_class_weight': 1075.509814980568}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:05:19,717] Trial 97 finished with value: 0.1577713036002346 and parameters: {'min_child_samples': 420, 'n_estimators': 500, 'learning_rate': 0.003539197616917249, 'reg_alpha': 0.001152488809057357, 'reg_lambda': 0.17729358140391968, 'num_leaves': 216, 'max_depth': 45, 'subsample': 0.4454435662651652, 'colsample_bytree': 0.4193605606847936, 'pos_class_weight': 1075.509814980568}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17365604171454369
# Fold 2 - PAUC: 0.15305458290050622
# Fold 3 - PAUC: 0.1724992136470553
# Fold 4 - PAUC: 0.15715053211215838
# Fold 5 - PAUC: 0.16229560563355624
# Trial 98 finished with value: 0.16373119520156396 and parameters: {'min_child_samples': 399, 'n_estimators': 9400, 'learning_rate': 0.008297840329064714, 'reg_alpha': 0.002659783214067985, 'reg_lambda': 0.26268711972296266, 'num_leaves': 204, 'max_depth': 57, 'subsample': 0.5040524351856899, 'colsample_bytree': 0.4810048326591245, 'pos_class_weight': 1198.9853121097533}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:08:11,641] Trial 98 finished with value: 0.16373119520156396 and parameters: {'min_child_samples': 399, 'n_estimators': 9400, 'learning_rate': 0.008297840329064714, 'reg_alpha': 0.002659783214067985, 'reg_lambda': 0.26268711972296266, 'num_leaves': 204, 'max_depth': 57, 'subsample': 0.5040524351856899, 'colsample_bytree': 0.4810048326591245, 'pos_class_weight': 1198.9853121097533}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.17509561095554552
# Fold 2 - PAUC: 0.15506091604635003
# Fold 3 - PAUC: 0.17443948154142455
# Fold 4 - PAUC: 0.15707927237634095
# Fold 5 - PAUC: 0.163516011773284
# Trial 99 finished with value: 0.16503825853858903 and parameters: {'min_child_samples': 438, 'n_estimators': 8900, 'learning_rate': 0.005636499582304092, 'reg_alpha': 0.0017472776795077244, 'reg_lambda': 0.0326493270906115, 'num_leaves': 240, 'max_depth': 34, 'subsample': 0.5293876166442719, 'colsample_bytree': 0.41413129267118165, 'pos_class_weight': 1116.5916066210646}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:12:48,045] Trial 99 finished with value: 0.16503825853858903 and parameters: {'min_child_samples': 438, 'n_estimators': 8900, 'learning_rate': 0.005636499582304092, 'reg_alpha': 0.0017472776795077244, 'reg_lambda': 0.0326493270906115, 'num_leaves': 240, 'max_depth': 34, 'subsample': 0.5293876166442719, 'colsample_bytree': 0.41413129267118165, 'pos_class_weight': 1116.5916066210646}. Best is trial 88 with value: 0.16572092767462507.
# Fold 1 - PAUC: 0.1700748000346173
# Fold 2 - PAUC: 0.14718416175277274
# Fold 3 - PAUC: 0.17158371643040876
# Fold 4 - PAUC: 0.15244236584882756
# Fold 5 - PAUC: 0.16194044932766805
# Trial 100 finished with value: 0.16064509867885887 and parameters: {'min_child_samples': 385, 'n_estimators': 5800, 'learning_rate': 0.025952236314508607, 'reg_alpha': 0.001801658436879408, 'reg_lambda': 0.027985844619676178, 'num_leaves': 250, 'max_depth': 32, 'subsample': 0.5557710850703061, 'colsample_bytree': 0.4132146673121141, 'pos_class_weight': 1118.840535786252}. Best is trial 88 with value: 0.16572092767462507.
# [I 2024-08-02 05:13:56,637] Trial 100 finished with value: 0.16064509867885887 and parameters: {'min_child_samples': 385, 'n_estimators': 5800, 'learning_rate': 0.025952236314508607, 'reg_alpha': 0.001801658436879408, 'reg_lambda': 0.027985844619676178, 'num_leaves': 250, 'max_depth': 32, 'subsample': 0.5557710850703061, 'colsample_bytree': 0.4132146673121141, 'pos_class_weight': 1118.840535786252}. Best is trial 88 with value: 0.16572092767462507.

# %%
study.best_params
# Out:
# {'min_child_samples': 485,
#  'n_estimators': 8400,
#  'learning_rate': 0.007512103292915293,
#  'reg_alpha': 0.0027291905128624325,
#  'reg_lambda': 0.23105994775417862,
#  'num_leaves': 191,
#  'max_depth': 39,
#  'subsample': 0.45990831207544924,
#  'colsample_bytree': 0.4649846963529439,
#  'pos_class_weight': 545.918879501255}

# %%
{
    'seed': SEED,
    'objective': 'binary',
    'boosting_type': 'gbdt',
    'min_child_samples': 485,
    'num_iterations': 8400,
    'learning_rate': 0.007512103292915293,
    'reg_alpha': 0.0027291905128624325,
    'reg_lambda': 0.2310599477541786,
    "num_leaves":191,
    "max_depth": 39,
    'device': 'gpu',
    'verbose': -1,
    "subsample": 0.45990831207544924,
    "colsample_bytree": 545.918879501255,
}

# %% [markdown]
# ### Inference

# %%
for col in categorical_cols:
    test_df[col] = test_df[col].astype('category')
    
lgb_preds = np.mean([model.predict(test_df[train_cols])for model in models], 0)

# %% [markdown]
# ### Submission

# %%
sub = pd.DataFrame(columns=['isic_id', 'target'])
sub['isic_id'] = test_metadata['isic_id']
sub['target'] = lgb_preds

# %%
sub[['isic_id', 'target']].to_csv('submission.csv', index=False)
# !head submission.csv
# Out:
# isic_id,target
# ISIC_0015657,0.00010571025692889189
# ISIC_0015729,7.672189515860861e-05
# ISIC_0015740,0.00022154247309468452
